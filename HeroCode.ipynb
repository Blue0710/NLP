# %%
import nltk
import re
english='C:/Users/USER/Desktop/Blue/107-2CRM/期末報告/美國隊長.txt'
#character = ['Spider Man','幻視','奇異博士','美國隊長','浩克','索爾','黑豹','黑寡婦','緋紅女巫','鋼鐵人','薩諾斯','蟻人','驚奇隊長','鷹眼']
#for i in range(14):
    #file = english + character[i]+'.txt'
with open(english,'r',encoding = 'utf-8') as file:
    u=file.read()
str=re.sub('[^\w ]','',u)
str0 = nltk.word_tokenize(str)
print(str0)
str1 = nltk.pos_tag(nltk.word_tokenize(str))
print(str1) #对分完词的结果进行词性标注
#-------------------------------------------------------------------
import jieba.analyse,csv
from jieba import analyse
import pandas as pd
#nltk.download('stopwords')
stopwords = analyse.set_stop_words("C:/Users/USER/Desktop/Blue/107-2CRM/期末報告/stopwords.txt")
a=jieba.analyse.extract_tags(u, topK=30, withWeight=False,allowPOS=())
print(a)
#-------------------------------------------------------------------
import numpy as np
from jieba import analyse
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import gensim
import pandas as pd
# jieba分詞轉word2vec向量
# text = open("C:/Users/USER/Desktop/Blue/107-2CRM/期末報告/美國隊長keyword.txt").read()
#text = 'Jason blue is so handsome and handsome.'
# words = ' '.join(text)
# stopwords = analyse.set_stop_words("C:/Users/USER/Desktop/Blue/107-2CRM/期末報告/stopwords.txt")

import PIL.Image as image
import numpy as np
STOPWORDS = "C:/Users/USER/Desktop/Blue/107-2CRM/期末報告/stopwords.txt" 
with open("C:/Users/USER/Desktop/Blue/107-2CRM/期末報告/美國隊長.txt") as fp:
    text = fp.read()
    # print(text)
    mask = np.array(image.open("C:/Users/USER/Desktop/Blue/107-2CRM/期末報告/love.jpg"))
    wordcloud = WordCloud(
        mask=mask
                         ).generate(text)
    image_produce = wordcloud.to_image()
    image_produce.show()
# Out:
# ['Captain', 'America', 'Steven', 'RogersEarly', 'LifeSteve', 'Rogers', 'was', 'born', 'July', '423', '19224', 'to', 'poor', 'Irish', 'immigrant', 'parents', 'Sarah', 'and', 'Joseph', 'Rogers24', 'Rogers', 'grew', 'up', 'a', 'frail', 'youth', 'during', 'the', 'Great', 'Depression', 'in', 'New', 'York', 'City', 'New', 'York', 'America', 'Little', 'else', 'is', 'known', 'about', 'Rogers', 'early', 'life', 'other', 'than', 'the', 'fact', 'that', 'a', 'strong', 'sense', 'of', 'duty', 'honor', 'and', 'humility', 'was', 'instilled', 'in', 'him', 'perhaps', 'due', 'to', 'his', 'Irish', 'Catholic', 'upbringing', 'Rogers', 'father', 'died', 'when', 'he', 'was', 'a', 'child', 'and', 'his', 'mother', 'died', 'from', 'pneumonia', 'later', 'when', 'he', 'was', 'in', 'his', 'late', 'teens2526Becoming', 'Americas', 'SuperSoldierHorrified', 'by', 'newsreel', 'footage', 'of', 'Nazis', 'ransacking', 'Europe', 'and', 'atrocities', 'in', 'Asia', 'that', 'the', 'Empire', 'of', 'Japan', 'committed', 'in', 
# ...
